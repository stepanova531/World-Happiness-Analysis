# %% [markdown]
# # World Happines Analysis

# %% [markdown]
# ## Content
# ### 01. Importing libraries and data
# ### 02. Wrangling Data
# ### 03. Adding Year column to each dataframe
# ### 04. Removing columns 'region'
# ### 05. Checking for the columns names after wrangling data
# ### 06. Exporting Data

# %% [markdown]
# ## 01. Importing libraries and data

# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Create Path
path=r'C:\Users\Oksana Stepanova\OneDrive\Документи\World Happiness'

# %%
# 2015 Import data
wh_2015=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2015.csv'))

# %%
# 2015 Check for output
wh_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
wh_2015.shape
# Out:
# (158, 12)

# %%
wh_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
wh_2015.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
# 2016-2019 Import data
wh_2016=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2016.csv'))
wh_2017=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2017.csv'))
wh_2018=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2018.csv'))
wh_2019=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2019.csv'))

# %%
# 2020-2023 Import data
wh_2020=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2020.csv'))
wh_2021=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2021.csv'))
wh_2022=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2022.csv'))
wh_2023=pd.read_csv(os.path.join(path, '02 Data', 'Original Data', '2023.csv'))

# %%
# Check for the number of rows and columns
wh_2016.shape
# Out:
# (157, 13)

# %%
wh_2017.shape
# Out:
# (155, 12)

# %%
wh_2018.shape
# Out:
# (156, 9)

# %%
wh_2019.shape
# Out:
# (156, 9)

# %%
wh_2020.shape
# Out:
# (153, 20)

# %%
wh_2021.shape
# Out:
# (149, 20)

# %%
wh_2022.shape
# Out:
# (147, 12)

# %%
wh_2023.shape
# Out:
# (137, 9)

# %%
# Check for the columns names
wh_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
wh_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
wh_2018.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
wh_2019.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
wh_2020.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
wh_2021.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
wh_2022.columns
# Out:
# Index(['RANK', 'Country', 'Happiness score', 'Whisker-high', 'Whisker-low',
#        'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption'],
#       dtype='object')

# %%
wh_2023.columns
# Out:
# Index(['country', 'region', 'happiness_score', 'gdp_per_capita',
#        'social_support', 'healthy_life_expectancy',
#        'freedom_to_make_life_choices', 'generosity',
#        'perceptions_of_corruption'],
#       dtype='object')

# %% [markdown]
# ## 02. Wrangling Data

# %% [markdown]
# ### 2.1. Wrangling data - 2015 year

# %%
# 2015 checking the file
pd.options.display.max_columns = None
wh_2015.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
# Drop irrelevant columns
wh_2015.drop(columns=['Standard Error'])
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.587                   1.39651  1.34951
# 1              7.561                   1.30232  1.40223
# ...

# %%
wh_2015_1=wh_2015.drop(columns=['Standard Error'])

# %%
wh_2015_1.shape
# Out:
# (158, 11)

# %%
# Rename columns on 2015 dataframe
wh_2015_1.rename(columns={'Country':'country', 'Region':'region', 'Happiness Rank':'happiness_rank', 'Happiness Score':'happiness_score', 'Economy (GDP per Capita)':'economy_GDP_per_capita', 'Family':'family', 'Health (Life Expectancy)':'health_life_expectancy', 'Freedom':'freedom', 'Trust (Government Corruption)':'trust_government_corruption', 'Generosity':'generosity', 'Dystopia Residual':'dystopia_residual'}, inplace=True)

# %%
wh_2015_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      158 non-null    object
#  1   region                       158 non-null    object
#  2   happiness_rank               158 non-null    int64
#  3   happiness_score              158 non-null    float64
#  4   economy_GDP_per_capita       158 non-null    float64
#  5   family                       158 non-null    float64
#  6   health_life_expectancy       158 non-null    float64
#  7   freedom                      158 non-null    float64
#  8   trust_government_corruption  158 non-null    float64
#  9   generosity                   158 non-null    float64
#  10  dystopia_residual            158 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 13.7+ KB

# %% [markdown]
# ### 2.2. Wrangling data - 2016 year

# %%
# 2016 Check for original dataframe
wh_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
# 2016 Drop irrelevant columns
wh_2016.drop(columns=['Lower Confidence Interval', 'Upper Confidence Interval'])
# Out:
#          Country                           Region  Happiness Rank  \
# 0        Denmark                   Western Europe               1
# 1    Switzerland                   Western Europe               2
# 2        Iceland                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4        Finland                   Western Europe               5
# ..           ...                              ...             ...
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Economy (GDP per Capita)   Family  \
# 0              7.526                   1.44178  1.16374
# 1              7.509                   1.52733  1.14524
# ...

# %%
wh_2016_1=wh_2016.drop(columns=['Lower Confidence Interval', 'Upper Confidence Interval'])

# %%
wh_2016_1.shape
# Out:
# (157, 11)

# %%
# 2016 Rename columns
wh_2016_1.rename(columns={'Country':'country', 'Region':'region', 'Happiness Rank':'happiness_rank', 'Happiness Score':'happiness_score', 'Economy (GDP per Capita)':'economy_GDP_per_capita', 'Family':'family', 'Health (Life Expectancy)':'health_life_expectancy', 'Freedom':'freedom', 'Trust (Government Corruption)':'trust_government_corruption', 'Generosity':'generosity', 'Dystopia Residual':'dystopia_residual'}, inplace=True)

# %%
wh_2016_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      157 non-null    object
#  1   region                       157 non-null    object
#  2   happiness_rank               157 non-null    int64
#  3   happiness_score              157 non-null    float64
#  4   economy_GDP_per_capita       157 non-null    float64
#  5   family                       157 non-null    float64
#  6   health_life_expectancy       157 non-null    float64
#  7   freedom                      157 non-null    float64
#  8   trust_government_corruption  157 non-null    float64
#  9   generosity                   157 non-null    float64
#  10  dystopia_residual            157 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 13.6+ KB

# %% [markdown]
# ### 2.3. Wrangling data - 2017 year

# %%
# 2017 Check for the original dataframe
wh_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
# 2017 Drop irrelevant columns
wh_2017.drop(columns=['Whisker.high', 'Whisker.low'])
# Out:
#                       Country  Happiness.Rank  Happiness.Score  \
# 0                      Norway               1            7.537
# 1                     Denmark               2            7.522
# 2                     Iceland               3            7.504
# 3                 Switzerland               4            7.494
# 4                     Finland               5            7.469
# ..                        ...             ...              ...
# 150                    Rwanda             151            3.471
# 151                     Syria             152            3.462
# 152                  Tanzania             153            3.349
# 153                   Burundi             154            2.905
# 154  Central African Republic             155            2.693
#
#      Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                    1.616463  1.533524                  0.796667  0.635423
# ...

# %%
wh_2017_1=wh_2017.drop(columns=['Whisker.high', 'Whisker.low'])

# %%
wh_2017_1.shape
# Out:
# (155, 10)

# %%
# 2017 Rename columns
wh_2017_1.rename(columns={'Country':'country', 'Happiness.Rank':'happiness_rank', 'Happiness.Score':'happiness_score', 'Economy..GDP.per.Capita.':'economy_GDP_per_capita', 'Family':'family', 'Health..Life.Expectancy.':'health_life_expectancy', 'Freedom':'freedom', 'Generosity':'generosity', 'Trust..Government.Corruption.':'trust_government_corruption', 'Dystopia.Residual':'dystopia_residual'}, inplace=True)

# %%
wh_2017_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      155 non-null    object
#  1   happiness_rank               155 non-null    int64
#  2   happiness_score              155 non-null    float64
#  3   economy_GDP_per_capita       155 non-null    float64
#  4   family                       155 non-null    float64
#  5   health_life_expectancy       155 non-null    float64
#  6   freedom                      155 non-null    float64
#  7   generosity                   155 non-null    float64
#  8   trust_government_corruption  155 non-null    float64
#  9   dystopia_residual            155 non-null    float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 12.2+ KB

# %%
# 2017 Place 'generocity' column before 'dystopia_residual'
eighth_column=wh_2017_1.pop('generosity')

# %%
wh_2017_1.insert(8, 'generosity', eighth_column)

# %%
wh_2017_1.head()
# Out:
#        country  happiness_rank  happiness_score  economy_GDP_per_capita  \
# 0       Norway               1            7.537                1.616463
# 1      Denmark               2            7.522                1.482383
# 2      Iceland               3            7.504                1.480633
# 3  Switzerland               4            7.494                1.564980
# 4      Finland               5            7.469                1.443572
#
#      family  health_life_expectancy   freedom  trust_government_corruption  \
# 0  1.533524                0.796667  0.635423                     0.315964
# 1  1.551122                0.792566  0.626007                     0.400770
# 2  1.610574                0.833552  0.627163                     0.153527
# 3  1.516912                0.858131  0.620071                     0.367007
# 4  1.540247                0.809158  0.617951                     0.382612
#
#    generosity  dystopia_residual
# 0    0.362012           2.277027
# ...

# %% [markdown]
# ### 2.4. Wrangling data - 2018 year

# %%
wh_2018.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.632           1.305           1.592
# 1             2            Norway  7.594           1.456           1.582
# 2             3           Denmark  7.555           1.351           1.590
# 3             4           Iceland  7.495           1.343           1.644
# 4             5       Switzerland  7.487           1.420           1.549
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.874                         0.681       0.202
# 1                    0.861                         0.686       0.286
# 2                    0.868                         0.683       0.284
# 3                    0.914                         0.677       0.353
# 4                    0.927                         0.660       0.256
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.340
# ...

# %%
# 2018 Rename columns
wh_2018.rename(columns={'Overall rank':'happiness_rank', 'Country or region':'country', 'Score':'happiness_score', 'GDP per capita':'economy_GDP_per_capita',  'Social support':'family', 'Healthy life expectancy':'health_life_expectancy', 'Freedom to make life choices':'freedom', 'Generosity':'generosity', 'Perceptions of corruption':'trust_government_corruption'}, inplace=True)

# %%
wh_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   happiness_rank               156 non-null    int64
#  1   country                      156 non-null    object
#  2   happiness_score              156 non-null    float64
#  3   economy_GDP_per_capita       156 non-null    float64
#  4   family                       156 non-null    float64
#  5   health_life_expectancy       156 non-null    float64
#  6   freedom                      156 non-null    float64
#  7   generosity                   156 non-null    float64
#  8   trust_government_corruption  155 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# 2018 Place the 'happiness_rank' column after 'country'
first_column=wh_2018.pop('happiness_rank')

# %%
wh_2018.insert(1, 'happiness_rank', first_column)

# %%
wh_2018.head()
# Out:
#        country  happiness_rank  happiness_score  economy_GDP_per_capita  \
# 0      Finland               1            7.632                   1.305
# 1       Norway               2            7.594                   1.456
# 2      Denmark               3            7.555                   1.351
# 3      Iceland               4            7.495                   1.343
# 4  Switzerland               5            7.487                   1.420
#
#    family  health_life_expectancy  freedom  generosity  \
# 0   1.592                   0.874    0.681       0.202
# 1   1.582                   0.861    0.686       0.286
# 2   1.590                   0.868    0.683       0.284
# 3   1.644                   0.914    0.677       0.353
# 4   1.549                   0.927    0.660       0.256
#
#    trust_government_corruption
# 0                        0.393
# 1                        0.340
# 2                        0.408
# 3                        0.138
# 4                        0.357

# %%
# 2018 Place the 'generosity' column after 'trust_government_corruption'
eighth_column=wh_2018.pop('generosity')

# %%
wh_2018.insert(8, 'generosity', eighth_column)

# %%
wh_2018.head()
# Out:
#        country  happiness_rank  happiness_score  economy_GDP_per_capita  \
# 0      Finland               1            7.632                   1.305
# 1       Norway               2            7.594                   1.456
# 2      Denmark               3            7.555                   1.351
# 3      Iceland               4            7.495                   1.343
# 4  Switzerland               5            7.487                   1.420
#
#    family  health_life_expectancy  freedom  trust_government_corruption  \
# 0   1.592                   0.874    0.681                        0.393
# 1   1.582                   0.861    0.686                        0.340
# 2   1.590                   0.868    0.683                        0.408
# 3   1.644                   0.914    0.677                        0.138
# 4   1.549                   0.927    0.660                        0.357
#
#    generosity
# 0       0.202
# 1       0.286
# 2       0.284
# 3       0.353
# 4       0.256

# %%
# 2018 add a new column 'dystopia_residual' and assign zero value
wh_2018.insert(9, 'dystopia_residual', 0)

# %%
wh_2018.head()
# Out:
#        country  happiness_rank  happiness_score  economy_GDP_per_capita  \
# 0      Finland               1            7.632                   1.305
# 1       Norway               2            7.594                   1.456
# 2      Denmark               3            7.555                   1.351
# 3      Iceland               4            7.495                   1.343
# 4  Switzerland               5            7.487                   1.420
#
#    family  health_life_expectancy  freedom  trust_government_corruption  \
# 0   1.592                   0.874    0.681                        0.393
# 1   1.582                   0.861    0.686                        0.340
# 2   1.590                   0.868    0.683                        0.408
# 3   1.644                   0.914    0.677                        0.138
# 4   1.549                   0.927    0.660                        0.357
#
#    generosity  dystopia_residual
# 0       0.202                  0
# ...

# %%
wh_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      156 non-null    object
#  1   happiness_rank               156 non-null    int64
#  2   happiness_score              156 non-null    float64
#  3   economy_GDP_per_capita       156 non-null    float64
#  4   family                       156 non-null    float64
#  5   health_life_expectancy       156 non-null    float64
#  6   freedom                      156 non-null    float64
#  7   trust_government_corruption  155 non-null    float64
#  8   generosity                   156 non-null    float64
#  9   dystopia_residual            156 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 12.3+ KB

# %% [markdown]
# ### 2.5. Wrangling data - 2019 year

# %%
wh_2019.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
# 2019 Rename columns
wh_2019.rename(columns={'Overall rank':'happiness_rank', 'Country or region':'country', 'Score':'happiness_score', 'GDP per capita':'economy_GDP_per_capita', 'Social support':'family', 'Healthy life expectancy':'health_life_expectancy', 'Freedom to make life choices':'freedom', 'Generosity':'generosity', 'Perceptions of corruption':'trust_government_corruption'}, inplace=True)

# %%
wh_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   happiness_rank               156 non-null    int64
#  1   country                      156 non-null    object
#  2   happiness_score              156 non-null    float64
#  3   economy_GDP_per_capita       156 non-null    float64
#  4   family                       156 non-null    float64
#  5   health_life_expectancy       156 non-null    float64
#  6   freedom                      156 non-null    float64
#  7   generosity                   156 non-null    float64
#  8   trust_government_corruption  156 non-null    float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 11.1+ KB

# %%
# 2019 Place the 'happiness_rank' column after 'country'
first_column=wh_2019.pop('happiness_rank')
wh_2019.insert(1, 'happiness_rank', first_column)
wh_2019.head()
# Out:
#        country  happiness_rank  happiness_score  economy_GDP_per_capita  \
# 0      Finland               1            7.769                   1.340
# 1      Denmark               2            7.600                   1.383
# 2       Norway               3            7.554                   1.488
# 3      Iceland               4            7.494                   1.380
# 4  Netherlands               5            7.488                   1.396
#
#    family  health_life_expectancy  freedom  generosity  \
# 0   1.587                   0.986    0.596       0.153
# 1   1.573                   0.996    0.592       0.252
# 2   1.582                   1.028    0.603       0.271
# 3   1.624                   1.026    0.591       0.354
# 4   1.522                   0.999    0.557       0.322
#
#    trust_government_corruption
# 0                        0.393
# 1                        0.410
# 2                        0.341
# 3                        0.118
# 4                        0.298

# %%
# 2019 Place the 'generosity' column after 'trust_government_corruption'
eighth_column=wh_2019.pop('generosity')
wh_2019.insert(8, 'generosity', eighth_column)
wh_2019.head()
# Out:
#        country  happiness_rank  happiness_score  economy_GDP_per_capita  \
# 0      Finland               1            7.769                   1.340
# 1      Denmark               2            7.600                   1.383
# 2       Norway               3            7.554                   1.488
# 3      Iceland               4            7.494                   1.380
# 4  Netherlands               5            7.488                   1.396
#
#    family  health_life_expectancy  freedom  trust_government_corruption  \
# 0   1.587                   0.986    0.596                        0.393
# 1   1.573                   0.996    0.592                        0.410
# 2   1.582                   1.028    0.603                        0.341
# 3   1.624                   1.026    0.591                        0.118
# 4   1.522                   0.999    0.557                        0.298
#
#    generosity
# 0       0.153
# 1       0.252
# 2       0.271
# 3       0.354
# 4       0.322

# %%
# 2019 add a new column 'dystopia_residual' to wh_2019 dataframe and assign zero value
wh_2019.insert(9, 'dystopia_residual', 0)

# %%
wh_2019.head()
# Out:
#        country  happiness_rank  happiness_score  economy_GDP_per_capita  \
# 0      Finland               1            7.769                   1.340
# 1      Denmark               2            7.600                   1.383
# 2       Norway               3            7.554                   1.488
# 3      Iceland               4            7.494                   1.380
# 4  Netherlands               5            7.488                   1.396
#
#    family  health_life_expectancy  freedom  trust_government_corruption  \
# 0   1.587                   0.986    0.596                        0.393
# 1   1.573                   0.996    0.592                        0.410
# 2   1.582                   1.028    0.603                        0.341
# 3   1.624                   1.026    0.591                        0.118
# 4   1.522                   0.999    0.557                        0.298
#
#    generosity  dystopia_residual
# 0       0.153                  0
# ...

# %%
wh_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      156 non-null    object
#  1   happiness_rank               156 non-null    int64
#  2   happiness_score              156 non-null    float64
#  3   economy_GDP_per_capita       156 non-null    float64
#  4   family                       156 non-null    float64
#  5   health_life_expectancy       156 non-null    float64
#  6   freedom                      156 non-null    float64
#  7   trust_government_corruption  156 non-null    float64
#  8   generosity                   156 non-null    float64
#  9   dystopia_residual            156 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 12.3+ KB

# %% [markdown]
# ### 2.6. Wrangling data - 2020 year

# %%
wh_2020.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe        7.8087
# 1      Denmark     Western Europe        7.6456
# 2  Switzerland     Western Europe        7.5599
# 3      Iceland     Western Europe        7.5045
# 4       Norway     Western Europe        7.4880
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                        0.031156      7.869766      7.747634
# 1                        0.033492      7.711245      7.579955
# 2                        0.035014      7.628528      7.491272
# 3                        0.059616      7.621347      7.387653
# 4                        0.034837      7.556281      7.419719
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0              10.639267        0.954330                71.900825
# 1              10.774001        0.955991                72.402504
# 2              10.979933        0.942847                74.102448
# ...

# %%
# 2020 Drop the irrelevant columns
wh_2020.drop(columns=['Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Ladder score in Dystopia'])
# Out:
#                  Country name  Regional indicator  Ladder score  \
# 0                     Finland      Western Europe        7.8087
# 1                     Denmark      Western Europe        7.6456
# 2                 Switzerland      Western Europe        7.5599
# 3                     Iceland      Western Europe        7.5045
# 4                      Norway      Western Europe        7.4880
# ..                        ...                 ...           ...
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 0                            1.285190                      1.499526
# ...

# %%
wh_2020_1=wh_2020.drop(columns=['Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Ladder score in Dystopia'])

# %%
wh_2020_1.shape
# Out:
# (153, 10)

# %%
# 2020 Rename columns
wh_2020_1.rename(columns={'Country name':'country', 'Regional indicator':'region', 'Ladder score':'happiness_score', 'Explained by: Log GDP per capita':'economy_GDP_per_capita', 'Explained by: Social support':'family', 'Explained by: Healthy life expectancy':'health_life_expectancy', 'Explained by: Freedom to make life choices':'freedom', 'Explained by: Generosity':'generosity', 'Explained by: Perceptions of corruption':'trust_government_corruption', 'Dystopia + residual':'dystopia_residual'}, inplace=True )

# %%
wh_2020_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      153 non-null    object
#  1   region                       153 non-null    object
#  2   happiness_score              153 non-null    float64
#  3   economy_GDP_per_capita       153 non-null    float64
#  4   family                       153 non-null    float64
#  5   health_life_expectancy       153 non-null    float64
#  6   freedom                      153 non-null    float64
#  7   generosity                   153 non-null    float64
#  8   trust_government_corruption  153 non-null    float64
#  9   dystopia_residual            153 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 12.1+ KB

# %%
# 2020 Create a new cloumn 'happiness_rank'
wh_2020_1['happiness_rank']=wh_2020_1['happiness_score'].rank(ascending=False)
wh_2020_1=wh_2020_1.sort_values(by='happiness_rank', ignore_index=True)
wh_2020_1
# Out:
#                       country              region  happiness_score  \
# 0                     Finland      Western Europe           7.8087
# 1                     Denmark      Western Europe           7.6456
# 2                 Switzerland      Western Europe           7.5599
# 3                     Iceland      Western Europe           7.5045
# 4                      Norway      Western Europe           7.4880
# ..                        ...                 ...              ...
# 148  Central African Republic  Sub-Saharan Africa           3.4759
# 149                    Rwanda  Sub-Saharan Africa           3.3123
# 150                  Zimbabwe  Sub-Saharan Africa           3.2992
# 151               South Sudan  Sub-Saharan Africa           2.8166
# 152               Afghanistan          South Asia           2.5669
#
#      economy_GDP_per_capita    family  health_life_expectancy   freedom  \
# 0                  1.285190  1.499526                0.961271  0.662317
# ...

# %%
wh_2020_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      153 non-null    object
#  1   region                       153 non-null    object
#  2   happiness_score              153 non-null    float64
#  3   economy_GDP_per_capita       153 non-null    float64
#  4   family                       153 non-null    float64
#  5   health_life_expectancy       153 non-null    float64
#  6   freedom                      153 non-null    float64
#  7   generosity                   153 non-null    float64
#  8   trust_government_corruption  153 non-null    float64
#  9   dystopia_residual            153 non-null    float64
#  10  happiness_rank               153 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 13.3+ KB

# %%
# 2020 Change data type of 'happiness_rank' from float to int
wh_2020_1['happiness_rank']=wh_2020_1['happiness_rank'].apply(np.int64)

# %%
wh_2020_1['happiness_rank'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 153 entries, 0 to 152
# Series name: happiness_rank
# Non-Null Count  Dtype
# --------------  -----
# 153 non-null    int64
# dtypes: int64(1)
# memory usage: 1.3 KB

# %%
# 2020 Place the 'happiness_rank' column after 'region'
second_column=wh_2020_1.pop('happiness_rank')
wh_2020_1.insert(2, 'happiness_rank', second_column)
wh_2020_1.head()
# Out:
#        country          region  happiness_rank  happiness_score  \
# 0      Finland  Western Europe               1           7.8087
# 1      Denmark  Western Europe               2           7.6456
# 2  Switzerland  Western Europe               3           7.5599
# 3      Iceland  Western Europe               4           7.5045
# 4       Norway  Western Europe               5           7.4880
#
#    economy_GDP_per_capita    family  health_life_expectancy   freedom  \
# 0                1.285190  1.499526                0.961271  0.662317
# 1                1.326949  1.503449                0.979333  0.665040
# 2                1.390774  1.472403                1.040533  0.628954
# 3                1.326502  1.547567                1.000843  0.661981
# 4                1.424207  1.495173                1.008072  0.670201
#
#    generosity  trust_government_corruption  dystopia_residual
# 0    0.159670                     0.477857           2.762835
# ...

# %%
wh_2020_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      153 non-null    object
#  1   region                       153 non-null    object
#  2   happiness_rank               153 non-null    int64
#  3   happiness_score              153 non-null    float64
#  4   economy_GDP_per_capita       153 non-null    float64
#  5   family                       153 non-null    float64
#  6   health_life_expectancy       153 non-null    float64
#  7   freedom                      153 non-null    float64
#  8   generosity                   153 non-null    float64
#  9   trust_government_corruption  153 non-null    float64
#  10  dystopia_residual            153 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 13.3+ KB

# %%
# 2020 Place the 'generosity' column after 'trust_government_corruption'
nineth_column=wh_2020_1.pop('generosity')
wh_2020_1.insert(9, 'generosity', nineth_column)
wh_2020_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      153 non-null    object
#  1   region                       153 non-null    object
#  2   happiness_rank               153 non-null    int64
#  3   happiness_score              153 non-null    float64
#  4   economy_GDP_per_capita       153 non-null    float64
#  5   family                       153 non-null    float64
#  6   health_life_expectancy       153 non-null    float64
#  7   freedom                      153 non-null    float64
#  8   trust_government_corruption  153 non-null    float64
#  9   generosity                   153 non-null    float64
#  10  dystopia_residual            153 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 13.3+ KB

# %% [markdown]
# ### 2.7. Wrangling data - 2021 year

# %%
wh_2021.head()
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
# 2021 Drop the irrelevant columns
wh_2021.drop(columns=['Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Ladder score in Dystopia'])
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Explained by: Log GDP per capita  Explained by: Social support  \
# 0                               1.446                         1.106
# 1                               1.502                         1.108
# 2                               1.566                         1.079
# 3                               1.482                         1.172
# ...

# %%
wh_2021_1=wh_2021.drop(columns=['Standard error of ladder score', 'upperwhisker', 'lowerwhisker', 'Logged GDP per capita', 'Social support', 'Healthy life expectancy', 'Freedom to make life choices', 'Generosity', 'Perceptions of corruption', 'Ladder score in Dystopia'])

# %%
# 2021 Rename columns
wh_2021_1.rename(columns={'Country name':'country', 'Regional indicator':'region', 'Ladder score':'happiness_score', 'Explained by: Log GDP per capita':'economy_GDP_per_capita', 'Explained by: Social support':'family', 'Explained by: Healthy life expectancy':'health_life_expectancy', 'Explained by: Freedom to make life choices':'freedom', 'Explained by: Generosity':'generosity', 'Explained by: Perceptions of corruption':'trust_government_corruption', 'Dystopia + residual':'dystopia_residual'}, inplace=True)

# %%
wh_2021_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      149 non-null    object
#  1   region                       149 non-null    object
#  2   happiness_score              149 non-null    float64
#  3   economy_GDP_per_capita       149 non-null    float64
#  4   family                       149 non-null    float64
#  5   health_life_expectancy       149 non-null    float64
#  6   freedom                      149 non-null    float64
#  7   generosity                   149 non-null    float64
#  8   trust_government_corruption  149 non-null    float64
#  9   dystopia_residual            149 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 11.8+ KB

# %%
# 2021 Create a new cloumn 'happiness_rank'
wh_2021_1['happiness_rank']=wh_2021_1['happiness_score'].rank(ascending=False)
wh_2021_1=wh_2021_1.sort_values(by='happiness_rank', ignore_index=True)
wh_2021_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      149 non-null    object
#  1   region                       149 non-null    object
#  2   happiness_score              149 non-null    float64
#  3   economy_GDP_per_capita       149 non-null    float64
#  4   family                       149 non-null    float64
#  5   health_life_expectancy       149 non-null    float64
#  6   freedom                      149 non-null    float64
#  7   generosity                   149 non-null    float64
#  8   trust_government_corruption  149 non-null    float64
#  9   dystopia_residual            149 non-null    float64
#  10  happiness_rank               149 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 12.9+ KB

# %%
# 2021 Change data type of 'happiness_rank' from float to int
wh_2021_1['happiness_rank']=wh_2021_1['happiness_rank'].apply(np.int64)
wh_2021_1['happiness_rank'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 149 entries, 0 to 148
# Series name: happiness_rank
# Non-Null Count  Dtype
# --------------  -----
# 149 non-null    int64
# dtypes: int64(1)
# memory usage: 1.3 KB

# %%
# 2021 Place the 'happiness_rank' column after 'region'
second_column=wh_2021_1.pop('happiness_rank')
wh_2021_1.insert(2, 'happiness_rank', second_column)
wh_2021_1.head()
# Out:
#        country          region  happiness_rank  happiness_score  \
# 0      Finland  Western Europe               1            7.842
# 1      Denmark  Western Europe               2            7.620
# 2  Switzerland  Western Europe               3            7.571
# 3      Iceland  Western Europe               4            7.554
# 4  Netherlands  Western Europe               5            7.464
#
#    economy_GDP_per_capita  family  health_life_expectancy  freedom  \
# 0                   1.446   1.106                   0.741    0.691
# 1                   1.502   1.108                   0.763    0.686
# 2                   1.566   1.079                   0.816    0.653
# 3                   1.482   1.172                   0.772    0.698
# 4                   1.501   1.079                   0.753    0.647
#
#    generosity  trust_government_corruption  dystopia_residual
# 0       0.124                        0.481              3.253
# ...

# %%
# 2021 Place the 'generosity' column after 'trust_government_corruption'
nineth_column=wh_2021_1.pop('generosity')
wh_2021_1.insert(9, 'generosity', nineth_column)
wh_2021_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      149 non-null    object
#  1   region                       149 non-null    object
#  2   happiness_rank               149 non-null    int64
#  3   happiness_score              149 non-null    float64
#  4   economy_GDP_per_capita       149 non-null    float64
#  5   family                       149 non-null    float64
#  6   health_life_expectancy       149 non-null    float64
#  7   freedom                      149 non-null    float64
#  8   trust_government_corruption  149 non-null    float64
#  9   generosity                   149 non-null    float64
#  10  dystopia_residual            149 non-null    float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 12.9+ KB

# %% [markdown]
# ### 2.8. Wrangling data - 2022 year

# %%
wh_2022.head()
# Out:
#    RANK      Country Happiness score Whisker-high Whisker-low  \
# 0     1      Finland           7,821        7,886       7,756
# 1     2      Denmark           7,636        7,710       7,563
# 2     3      Iceland           7,557        7,651       7,464
# 3     4  Switzerland           7,512        7,586       7,437
# 4     5  Netherlands           7,415        7,471       7,359
#
#   Dystopia (1.83) + residual Explained by: GDP per capita  \
# 0                      2,518                        1,892
# 1                      2,226                        1,953
# 2                      2,320                        1,936
# 3                      2,153                        2,026
# 4                      2,137                        1,945
#
#   Explained by: Social support Explained by: Healthy life expectancy  \
# 0                        1,258                                 0,775
# 1                        1,243                                 0,777
# ...

# %%
# 2022 Drop irrelevant columns
wh_2022.drop(columns=['Whisker-high', 'Whisker-low'])
# Out:
#      RANK      Country Happiness score Dystopia (1.83) + residual  \
# 0       1      Finland           7,821                      2,518
# 1       2      Denmark           7,636                      2,226
# 2       3      Iceland           7,557                      2,320
# 3       4  Switzerland           7,512                      2,153
# 4       5  Netherlands           7,415                      2,137
# ..    ...          ...             ...                        ...
# 142   143      Rwanda*           3,268                      0,536
# 143   144     Zimbabwe           2,995                      0,548
# 144   145      Lebanon           2,955                      0,216
# 145   146  Afghanistan           2,404                      1,263
# 146   147           xx             NaN                        NaN
#
#     Explained by: GDP per capita Explained by: Social support  \
# 0                          1,892                        1,258
# ...

# %%
wh_2022_1=wh_2022.drop(columns=['Whisker-high', 'Whisker-low'])

# %%
wh_2022_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 10 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RANK                                        147 non-null    int64
#  1   Country                                     147 non-null    object
#  2   Happiness score                             146 non-null    object
#  3   Dystopia (1.83) + residual                  146 non-null    object
#  4   Explained by: GDP per capita                146 non-null    object
#  5   Explained by: Social support                146 non-null    object
#  6   Explained by: Healthy life expectancy       146 non-null    object
#  7   Explained by: Freedom to make life choices  146 non-null    object
#  8   Explained by: Generosity                    146 non-null    object
#  9   Explained by: Perceptions of corruption     146 non-null    object
# ...

# %%
# 2022 Rename columns
wh_2022_1.rename(columns={'RANK':'happiness_rank', 'Country':'country', 'Happiness score':'happiness_score', 'Dystopia (1.83) + residual':'dystopia_residual', 'Explained by: GDP per capita':'economy_GDP_per_capita', 'Explained by: Social support':'family', 'Explained by: Healthy life expectancy':'health_life_expectancy', 'Explained by: Freedom to make life choices':'freedom', 'Explained by: Generosity':'generosity', 'Explained by: Perceptions of corruption':'trust_government_corruption'}, inplace=True)

# %%
wh_2022_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   happiness_rank               147 non-null    int64
#  1   country                      147 non-null    object
#  2   happiness_score              146 non-null    object
#  3   dystopia_residual            146 non-null    object
#  4   economy_GDP_per_capita       146 non-null    object
#  5   family                       146 non-null    object
#  6   health_life_expectancy       146 non-null    object
#  7   freedom                      146 non-null    object
#  8   generosity                   146 non-null    object
#  9   trust_government_corruption  146 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 11.6+ KB

# %%
# 2022 Place the 'happiness_rank' column after 'country'
first_column=wh_2022_1.pop('happiness_rank')
wh_2022_1.insert(1, 'happiness_rank', first_column)
wh_2022_1.head()
# Out:
#        country  happiness_rank happiness_score dystopia_residual  \
# 0      Finland               1           7,821             2,518
# 1      Denmark               2           7,636             2,226
# 2      Iceland               3           7,557             2,320
# 3  Switzerland               4           7,512             2,153
# 4  Netherlands               5           7,415             2,137
#
#   economy_GDP_per_capita family health_life_expectancy freedom generosity  \
# 0                  1,892  1,258                  0,775   0,736      0,109
# 1                  1,953  1,243                  0,777   0,719      0,188
# 2                  1,936  1,320                  0,803   0,718      0,270
# 3                  2,026  1,226                  0,822   0,677      0,147
# 4                  1,945  1,206                  0,787   0,651      0,271
#
#   trust_government_corruption
# 0                       0,534
# 1                       0,532
# 2                       0,191
# ...

# %%
# 2022 Place the 'generosity' column after 'trust_government_corruption'
nineth_column=wh_2022_1.pop('generosity')
wh_2022_1.insert(9, 'generosity', nineth_column)
wh_2022_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      147 non-null    object
#  1   happiness_rank               147 non-null    int64
#  2   happiness_score              146 non-null    object
#  3   dystopia_residual            146 non-null    object
#  4   economy_GDP_per_capita       146 non-null    object
#  5   family                       146 non-null    object
#  6   health_life_expectancy       146 non-null    object
#  7   freedom                      146 non-null    object
#  8   trust_government_corruption  146 non-null    object
#  9   generosity                   146 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 11.6+ KB

# %%
# 2022 Place the 'dystopia_residual' column at the end
nineth_column=wh_2022_1.pop('dystopia_residual')
wh_2022_1.insert(9, 'dystopia_residual', nineth_column)
wh_2022_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      147 non-null    object
#  1   happiness_rank               147 non-null    int64
#  2   happiness_score              146 non-null    object
#  3   economy_GDP_per_capita       146 non-null    object
#  4   family                       146 non-null    object
#  5   health_life_expectancy       146 non-null    object
#  6   freedom                      146 non-null    object
#  7   trust_government_corruption  146 non-null    object
#  8   generosity                   146 non-null    object
#  9   dystopia_residual            146 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 11.6+ KB

# %% [markdown]
# ### 2.9. Wrangling data - 2023 year

# %%
wh_2023.head()
# Out:
#        country                        region  happiness_score  gdp_per_capita  \
# 0      Finland                Western Europe            7.804           1.888
# 1      Denmark                Western Europe            7.586           1.949
# 2      Iceland                Western Europe            7.530           1.926
# 3       Israel  Middle East and North Africa            7.473           1.833
# 4  Netherlands                Western Europe            7.403           1.942
#
#    social_support  healthy_life_expectancy  freedom_to_make_life_choices  \
# 0           1.585                    0.535                         0.772
# 1           1.548                    0.537                         0.734
# 2           1.620                    0.559                         0.738
# 3           1.521                    0.577                         0.569
# 4           1.488                    0.545                         0.672
#
#    generosity  perceptions_of_corruption
# ...

# %%
# 2023 Rename columns
wh_2023.rename(columns={'gdp_per_capita':'economy_GDP_per_capita', 'social_support':'family', 'healthy_life_expectancy':'health_life_expectancy', 'freedom_to_make_life_choices':'freedom', 'perceptions_of_corruption':'trust_government_corruption'}, inplace=True)

# %%
wh_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      137 non-null    object
#  1   region                       137 non-null    object
#  2   happiness_score              137 non-null    float64
#  3   economy_GDP_per_capita       137 non-null    float64
#  4   family                       137 non-null    float64
#  5   health_life_expectancy       136 non-null    float64
#  6   freedom                      137 non-null    float64
#  7   generosity                   137 non-null    float64
#  8   trust_government_corruption  137 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 9.8+ KB

# %%
# 2023 Create a new cloumn 'happiness_rank'
wh_2023['happiness_rank']=wh_2023['happiness_score'].rank(ascending=False)
wh_2023=wh_2023.sort_values(by='happiness_rank', ignore_index=True)
wh_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      137 non-null    object
#  1   region                       137 non-null    object
#  2   happiness_score              137 non-null    float64
#  3   economy_GDP_per_capita       137 non-null    float64
#  4   family                       137 non-null    float64
#  5   health_life_expectancy       136 non-null    float64
#  6   freedom                      137 non-null    float64
#  7   generosity                   137 non-null    float64
#  8   trust_government_corruption  137 non-null    float64
#  9   happiness_rank               137 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 10.8+ KB

# %%
# 2023 Change data type of 'happiness_rank' from float to int
wh_2023['happiness_rank']=wh_2023['happiness_rank'].apply(np.int64)
wh_2023['happiness_rank'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 137 entries, 0 to 136
# Series name: happiness_rank
# Non-Null Count  Dtype
# --------------  -----
# 137 non-null    int64
# dtypes: int64(1)
# memory usage: 1.2 KB

# %%
# 2023 add a new column 'dystopia_residual' to wh_2023 dataframe and assign zero value
wh_2023.insert(10, 'dystopia_residual', 0)

# %%
wh_2023.head()
# Out:
#        country                        region  happiness_score  \
# 0      Finland                Western Europe            7.804
# 1      Denmark                Western Europe            7.586
# 2      Iceland                Western Europe            7.530
# 3       Israel  Middle East and North Africa            7.473
# 4  Netherlands                Western Europe            7.403
#
#    economy_GDP_per_capita  family  health_life_expectancy  freedom  \
# 0                   1.888   1.585                   0.535    0.772
# 1                   1.949   1.548                   0.537    0.734
# 2                   1.926   1.620                   0.559    0.738
# 3                   1.833   1.521                   0.577    0.569
# 4                   1.942   1.488                   0.545    0.672
#
#    generosity  trust_government_corruption  happiness_rank  dystopia_residual
# 0       0.126                        0.535               1                  0
# ...

# %%
wh_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      137 non-null    object
#  1   region                       137 non-null    object
#  2   happiness_score              137 non-null    float64
#  3   economy_GDP_per_capita       137 non-null    float64
#  4   family                       137 non-null    float64
#  5   health_life_expectancy       136 non-null    float64
#  6   freedom                      137 non-null    float64
#  7   generosity                   137 non-null    float64
#  8   trust_government_corruption  137 non-null    float64
#  9   happiness_rank               137 non-null    int64
#  10  dystopia_residual            137 non-null    int64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 11.9+ KB

# %%
# 2023 Place the 'happiness_rank' column after 'region'
second_column=wh_2023.pop('happiness_rank')
wh_2023.insert(2, 'happiness_rank', second_column)
wh_2023.head()
# Out:
#        country                        region  happiness_rank  happiness_score  \
# 0      Finland                Western Europe               1            7.804
# 1      Denmark                Western Europe               2            7.586
# 2      Iceland                Western Europe               3            7.530
# 3       Israel  Middle East and North Africa               4            7.473
# 4  Netherlands                Western Europe               5            7.403
#
#    economy_GDP_per_capita  family  health_life_expectancy  freedom  \
# 0                   1.888   1.585                   0.535    0.772
# 1                   1.949   1.548                   0.537    0.734
# 2                   1.926   1.620                   0.559    0.738
# 3                   1.833   1.521                   0.577    0.569
# 4                   1.942   1.488                   0.545    0.672
#
#    generosity  trust_government_corruption  dystopia_residual
# ...

# %%
wh_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      137 non-null    object
#  1   region                       137 non-null    object
#  2   happiness_rank               137 non-null    int64
#  3   happiness_score              137 non-null    float64
#  4   economy_GDP_per_capita       137 non-null    float64
#  5   family                       137 non-null    float64
#  6   health_life_expectancy       136 non-null    float64
#  7   freedom                      137 non-null    float64
#  8   generosity                   137 non-null    float64
#  9   trust_government_corruption  137 non-null    float64
#  10  dystopia_residual            137 non-null    int64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 11.9+ KB

# %%
# 2023 Place the 'generosity' column after 'trust_government_corruption'
ninth_column=wh_2023.pop('generosity')
wh_2023.insert(9, 'generosity', ninth_column)
wh_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      137 non-null    object
#  1   region                       137 non-null    object
#  2   happiness_rank               137 non-null    int64
#  3   happiness_score              137 non-null    float64
#  4   economy_GDP_per_capita       137 non-null    float64
#  5   family                       137 non-null    float64
#  6   health_life_expectancy       136 non-null    float64
#  7   freedom                      137 non-null    float64
#  8   trust_government_corruption  137 non-null    float64
#  9   generosity                   137 non-null    float64
#  10  dystopia_residual            137 non-null    int64
# dtypes: float64(7), int64(2), object(2)
# memory usage: 11.9+ KB

# %% [markdown]
# ## 03. Adding Year column to each dataframe

# %%
# 2015 Add a 'year' column after region columns
wh_2015_1.insert(2, 'year', 2015)

# %%
wh_2015_1.head()
# Out:
#        country          region  year  happiness_rank  happiness_score  \
# 0  Switzerland  Western Europe  2015               1            7.587
# 1      Iceland  Western Europe  2015               2            7.561
# 2      Denmark  Western Europe  2015               3            7.527
# 3       Norway  Western Europe  2015               4            7.522
# 4       Canada   North America  2015               5            7.427
#
#    economy_GDP_per_capita   family  health_life_expectancy  freedom  \
# 0                 1.39651  1.34951                 0.94143  0.66557
# 1                 1.30232  1.40223                 0.94784  0.62877
# 2                 1.32548  1.36058                 0.87464  0.64938
# 3                 1.45900  1.33095                 0.88521  0.66973
# 4                 1.32629  1.32261                 0.90563  0.63297
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                      0.41978     0.29678            2.51738
# ...

# %%
wh_2015_1['year'].value_counts(dropna=False)
# Out:
# year
# 2015    158
# Name: count, dtype: int64

# %%
wh_2015_1['year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 158 entries, 0 to 157
# Series name: year
# Non-Null Count  Dtype
# --------------  -----
# 158 non-null    int64
# dtypes: int64(1)
# memory usage: 1.4 KB

# %%
wh_2015_1.shape
# Out:
# (158, 12)

# %%
# 2016 Add a 'year' column after region columns
wh_2016_1.insert(2, 'year', 2016)

# %%
wh_2016_1.head()
# Out:
#        country          region  year  happiness_rank  happiness_score  \
# 0      Denmark  Western Europe  2016               1            7.526
# 1  Switzerland  Western Europe  2016               2            7.509
# 2      Iceland  Western Europe  2016               3            7.501
# 3       Norway  Western Europe  2016               4            7.498
# 4      Finland  Western Europe  2016               5            7.413
#
#    economy_GDP_per_capita   family  health_life_expectancy  freedom  \
# 0                 1.44178  1.16374                 0.79504  0.57941
# 1                 1.52733  1.14524                 0.86303  0.58557
# 2                 1.42666  1.18326                 0.86733  0.56624
# 3                 1.57744  1.12690                 0.79579  0.59609
# 4                 1.40598  1.13464                 0.81091  0.57104
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                      0.44453     0.36171            2.73939
# ...

# %%
wh_2016_1['year'].value_counts(dropna=False)
# Out:
# year
# 2016    157
# Name: count, dtype: int64

# %%
wh_2016_1['year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 157 entries, 0 to 156
# Series name: year
# Non-Null Count  Dtype
# --------------  -----
# 157 non-null    int64
# dtypes: int64(1)
# memory usage: 1.4 KB

# %%
wh_2016_1.shape
# Out:
# (157, 12)

# %%
# 2017 Add a 'year' column after country columns
wh_2017_1.insert(1, 'year', 2017)

# %%
wh_2017_1.head()
# Out:
#        country  year  happiness_rank  happiness_score  economy_GDP_per_capita  \
# 0       Norway  2017               1            7.537                1.616463
# 1      Denmark  2017               2            7.522                1.482383
# 2      Iceland  2017               3            7.504                1.480633
# 3  Switzerland  2017               4            7.494                1.564980
# 4      Finland  2017               5            7.469                1.443572
#
#      family  health_life_expectancy   freedom  trust_government_corruption  \
# 0  1.533524                0.796667  0.635423                     0.315964
# 1  1.551122                0.792566  0.626007                     0.400770
# 2  1.610574                0.833552  0.627163                     0.153527
# 3  1.516912                0.858131  0.620071                     0.367007
# 4  1.540247                0.809158  0.617951                     0.382612
#
#    generosity  dystopia_residual
# ...

# %%
wh_2017_1['year'].value_counts(dropna=False)
# Out:
# year
# 2017    155
# Name: count, dtype: int64

# %%
wh_2017_1.shape
# Out:
# (155, 11)

# %%
# 2018 Add a 'year' column after country columns
wh_2018.insert(1, 'year', 2018)

# %%
wh_2018.head()
# Out:
#        country  year  happiness_rank  happiness_score  economy_GDP_per_capita  \
# 0      Finland  2018               1            7.632                   1.305
# 1       Norway  2018               2            7.594                   1.456
# 2      Denmark  2018               3            7.555                   1.351
# 3      Iceland  2018               4            7.495                   1.343
# 4  Switzerland  2018               5            7.487                   1.420
#
#    family  health_life_expectancy  freedom  trust_government_corruption  \
# 0   1.592                   0.874    0.681                        0.393
# 1   1.582                   0.861    0.686                        0.340
# 2   1.590                   0.868    0.683                        0.408
# 3   1.644                   0.914    0.677                        0.138
# 4   1.549                   0.927    0.660                        0.357
#
#    generosity  dystopia_residual
# ...

# %%
wh_2018['year'].value_counts(dropna=False)
# Out:
# year
# 2018    156
# Name: count, dtype: int64

# %%
wh_2018.shape
# Out:
# (156, 11)

# %%
# 2019 Add a 'year' column after country columns
wh_2019.insert(1, 'year', 2019)

# %%
wh_2019.head()
# Out:
#        country  year  happiness_rank  happiness_score  economy_GDP_per_capita  \
# 0      Finland  2019               1            7.769                   1.340
# 1      Denmark  2019               2            7.600                   1.383
# 2       Norway  2019               3            7.554                   1.488
# 3      Iceland  2019               4            7.494                   1.380
# 4  Netherlands  2019               5            7.488                   1.396
#
#    family  health_life_expectancy  freedom  trust_government_corruption  \
# 0   1.587                   0.986    0.596                        0.393
# 1   1.573                   0.996    0.592                        0.410
# 2   1.582                   1.028    0.603                        0.341
# 3   1.624                   1.026    0.591                        0.118
# 4   1.522                   0.999    0.557                        0.298
#
#    generosity  dystopia_residual
# ...

# %%
wh_2019['year'].value_counts(dropna=False)
# Out:
# year
# 2019    156
# Name: count, dtype: int64

# %%
# 2020 Add a 'year' column after region columns
wh_2020_1.insert(2, 'year', 2020)

# %%
wh_2020_1.head()
# Out:
#        country          region  year  happiness_rank  happiness_score  \
# 0      Finland  Western Europe  2020               1           7.8087
# 1      Denmark  Western Europe  2020               2           7.6456
# 2  Switzerland  Western Europe  2020               3           7.5599
# 3      Iceland  Western Europe  2020               4           7.5045
# 4       Norway  Western Europe  2020               5           7.4880
#
#    economy_GDP_per_capita    family  health_life_expectancy   freedom  \
# 0                1.285190  1.499526                0.961271  0.662317
# 1                1.326949  1.503449                0.979333  0.665040
# 2                1.390774  1.472403                1.040533  0.628954
# 3                1.326502  1.547567                1.000843  0.661981
# 4                1.424207  1.495173                1.008072  0.670201
#
#    trust_government_corruption  generosity  dystopia_residual
# ...

# %%
wh_2020_1['year'].value_counts(dropna=False)
# Out:
# year
# 2020    153
# Name: count, dtype: int64

# %%
wh_2020_1.shape
# Out:
# (153, 12)

# %%
# 2021 Add a 'year' column after region columns
wh_2021_1.insert(2, 'year', 2021)

# %%
wh_2021_1.head()
# Out:
#        country          region  year  happiness_rank  happiness_score  \
# 0      Finland  Western Europe  2021               1            7.842
# 1      Denmark  Western Europe  2021               2            7.620
# 2  Switzerland  Western Europe  2021               3            7.571
# 3      Iceland  Western Europe  2021               4            7.554
# 4  Netherlands  Western Europe  2021               5            7.464
#
#    economy_GDP_per_capita  family  health_life_expectancy  freedom  \
# 0                   1.446   1.106                   0.741    0.691
# 1                   1.502   1.108                   0.763    0.686
# 2                   1.566   1.079                   0.816    0.653
# 3                   1.482   1.172                   0.772    0.698
# 4                   1.501   1.079                   0.753    0.647
#
#    trust_government_corruption  generosity  dystopia_residual
# 0                        0.481       0.124              3.253
# ...

# %%
wh_2021_1['year'].value_counts(dropna=False)
# Out:
# year
# 2021    149
# Name: count, dtype: int64

# %%
wh_2021_1.shape
# Out:
# (149, 12)

# %%
# 2022 Add a 'year' column after country columns
wh_2022_1.insert(1, 'year', 2022)

# %%
wh_2022_1.head()
# Out:
#        country  year  happiness_rank happiness_score economy_GDP_per_capita  \
# 0      Finland  2022               1           7,821                  1,892
# 1      Denmark  2022               2           7,636                  1,953
# 2      Iceland  2022               3           7,557                  1,936
# 3  Switzerland  2022               4           7,512                  2,026
# 4  Netherlands  2022               5           7,415                  1,945
#
#   family health_life_expectancy freedom trust_government_corruption  \
# 0  1,258                  0,775   0,736                       0,534
# 1  1,243                  0,777   0,719                       0,532
# 2  1,320                  0,803   0,718                       0,191
# 3  1,226                  0,822   0,677                       0,461
# 4  1,206                  0,787   0,651                       0,419
#
#   generosity dystopia_residual
# 0      0,109             2,518
# 1      0,188             2,226
# ...

# %%
wh_2022_1['year'].value_counts(dropna=False)
# Out:
# year
# 2022    147
# Name: count, dtype: int64

# %%
wh_2022_1.shape
# Out:
# (147, 11)

# %%
# 2023 Add a 'year' column after country columns
wh_2023.insert(2, 'year', 2023)

# %%
wh_2023['year'].value_counts(dropna=False)
# Out:
# year
# 2023    137
# Name: count, dtype: int64

# %%
wh_2023.shape
# Out:
# (137, 12)

# %% [markdown]
# ## 04. Removing columns 'region'

# %%
# 2015 Drop the column 'region'
wh_2015_1.drop(columns=['region'])
# Out:
#          country  year  happiness_rank  happiness_score  \
# 0    Switzerland  2015               1            7.587
# 1        Iceland  2015               2            7.561
# 2        Denmark  2015               3            7.527
# 3         Norway  2015               4            7.522
# 4         Canada  2015               5            7.427
# ..           ...   ...             ...              ...
# 153       Rwanda  2015             154            3.465
# 154        Benin  2015             155            3.340
# 155        Syria  2015             156            3.006
# 156      Burundi  2015             157            2.905
# 157         Togo  2015             158            2.839
#
#      economy_GDP_per_capita   family  health_life_expectancy  freedom  \
# 0                   1.39651  1.34951                 0.94143  0.66557
# 1                   1.30232  1.40223                 0.94784  0.62877
# 2                   1.32548  1.36058                 0.87464  0.64938
# ...

# %%
wh_2015_2=wh_2015_1.drop(columns=['region'])

# %%
wh_2015_2.shape
# Out:
# (158, 11)

# %%
# 2016 Drop the column 'region'
wh_2016_1.drop(columns=['region'])
# Out:
#          country  year  happiness_rank  happiness_score  \
# 0        Denmark  2016               1            7.526
# 1    Switzerland  2016               2            7.509
# 2        Iceland  2016               3            7.501
# 3         Norway  2016               4            7.498
# 4        Finland  2016               5            7.413
# ..           ...   ...             ...              ...
# 152        Benin  2016             153            3.484
# 153  Afghanistan  2016             154            3.360
# 154         Togo  2016             155            3.303
# 155        Syria  2016             156            3.069
# 156      Burundi  2016             157            2.905
#
#      economy_GDP_per_capita   family  health_life_expectancy  freedom  \
# 0                   1.44178  1.16374                 0.79504  0.57941
# 1                   1.52733  1.14524                 0.86303  0.58557
# 2                   1.42666  1.18326                 0.86733  0.56624
# ...

# %%
wh_2016_2=wh_2016_1.drop(columns=['region'])

# %%
wh_2016_2.shape
# Out:
# (157, 11)

# %%
# 2020 Drop the column 'region'
wh_2020_1.drop(columns=['region'])
# Out:
#                       country  year  happiness_rank  happiness_score  \
# 0                     Finland  2020               1           7.8087
# 1                     Denmark  2020               2           7.6456
# 2                 Switzerland  2020               3           7.5599
# 3                     Iceland  2020               4           7.5045
# 4                      Norway  2020               5           7.4880
# ..                        ...   ...             ...              ...
# 148  Central African Republic  2020             149           3.4759
# 149                    Rwanda  2020             150           3.3123
# 150                  Zimbabwe  2020             151           3.2992
# 151               South Sudan  2020             152           2.8166
# 152               Afghanistan  2020             153           2.5669
#
#      economy_GDP_per_capita    family  health_life_expectancy   freedom  \
# ...

# %%
wh_2020_2=wh_2020_1.drop(columns=['region'])

# %%
wh_2020_2.shape
# Out:
# (153, 11)

# %%
# 2021 Drop the column 'region'
wh_2021_1.drop(columns=['region'])
# Out:
#          country  year  happiness_rank  happiness_score  \
# 0        Finland  2021               1            7.842
# 1        Denmark  2021               2            7.620
# 2    Switzerland  2021               3            7.571
# 3        Iceland  2021               4            7.554
# 4    Netherlands  2021               5            7.464
# ..           ...   ...             ...              ...
# 144      Lesotho  2021             145            3.512
# 145     Botswana  2021             146            3.467
# 146       Rwanda  2021             147            3.415
# 147     Zimbabwe  2021             148            3.145
# 148  Afghanistan  2021             149            2.523
#
#      economy_GDP_per_capita  family  health_life_expectancy  freedom  \
# 0                     1.446   1.106                   0.741    0.691
# 1                     1.502   1.108                   0.763    0.686
# 2                     1.566   1.079                   0.816    0.653
# ...

# %%
wh_2021_2=wh_2021_1.drop(columns=['region'])

# %%
wh_2021_2.shape
# Out:
# (149, 11)

# %%
# 2023 Drop the column 'region'
wh_2023.drop(columns=['region'])
# Out:
#               country  year  happiness_rank  happiness_score  \
# 0             Finland  2023               1            7.804
# 1             Denmark  2023               2            7.586
# 2             Iceland  2023               3            7.530
# 3              Israel  2023               4            7.473
# 4         Netherlands  2023               5            7.403
# ..                ...   ...             ...              ...
# 132  Congo (Kinshasa)  2023             133            3.207
# 133          Zimbabwe  2023             134            3.204
# 134      Sierra Leone  2023             135            3.138
# 135           Lebanon  2023             136            2.392
# 136       Afghanistan  2023             137            1.859
#
#      economy_GDP_per_capita  family  health_life_expectancy  freedom  \
# 0                     1.888   1.585                   0.535    0.772
# 1                     1.949   1.548                   0.537    0.734
# ...

# %%
wh_2023_1=wh_2023.drop(columns=['region'])

# %%
wh_2023_1.shape
# Out:
# (137, 11)

# %% [markdown]
# ## 05. Checking for the columns names after wrangling data

# %%
wh_2015_2.columns
# Out:
# Index(['country', 'year', 'happiness_rank', 'happiness_score',
#        'economy_GDP_per_capita', 'family', 'health_life_expectancy', 'freedom',
#        'trust_government_corruption', 'generosity', 'dystopia_residual'],
#       dtype='object')

# %%
wh_2016_2.columns
# Out:
# Index(['country', 'year', 'happiness_rank', 'happiness_score',
#        'economy_GDP_per_capita', 'family', 'health_life_expectancy', 'freedom',
#        'trust_government_corruption', 'generosity', 'dystopia_residual'],
#       dtype='object')

# %%
wh_2017_1.columns
# Out:
# Index(['country', 'year', 'happiness_rank', 'happiness_score',
#        'economy_GDP_per_capita', 'family', 'health_life_expectancy', 'freedom',
#        'trust_government_corruption', 'generosity', 'dystopia_residual'],
#       dtype='object')

# %%
wh_2018.columns
# Out:
# Index(['country', 'year', 'happiness_rank', 'happiness_score',
#        'economy_GDP_per_capita', 'family', 'health_life_expectancy', 'freedom',
#        'trust_government_corruption', 'generosity', 'dystopia_residual'],
#       dtype='object')

# %%
wh_2019.columns
# Out:
# Index(['country', 'year', 'happiness_rank', 'happiness_score',
#        'economy_GDP_per_capita', 'family', 'health_life_expectancy', 'freedom',
#        'trust_government_corruption', 'generosity', 'dystopia_residual'],
#       dtype='object')

# %%
wh_2020_2.columns
# Out:
# Index(['country', 'year', 'happiness_rank', 'happiness_score',
#        'economy_GDP_per_capita', 'family', 'health_life_expectancy', 'freedom',
#        'trust_government_corruption', 'generosity', 'dystopia_residual'],
#       dtype='object')

# %%
wh_2021_2.columns
# Out:
# Index(['country', 'year', 'happiness_rank', 'happiness_score',
#        'economy_GDP_per_capita', 'family', 'health_life_expectancy', 'freedom',
#        'trust_government_corruption', 'generosity', 'dystopia_residual'],
#       dtype='object')

# %%
wh_2022_1.columns
# Out:
# Index(['country', 'year', 'happiness_rank', 'happiness_score',
#        'economy_GDP_per_capita', 'family', 'health_life_expectancy', 'freedom',
#        'trust_government_corruption', 'generosity', 'dystopia_residual'],
#       dtype='object')

# %%
wh_2023_1.columns
# Out:
# Index(['country', 'year', 'happiness_rank', 'happiness_score',
#        'economy_GDP_per_capita', 'family', 'health_life_expectancy', 'freedom',
#        'trust_government_corruption', 'generosity', 'dystopia_residual'],
#       dtype='object')

# %% [markdown]
# ## 06. Exporting Data

# %%
wh_2015_2.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'wh_2015_wrangled.csv'))

# %%
wh_2016_2.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'wh_2016_wrangled.csv'))

# %%
wh_2017_1.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'wh_2017_wrangled.csv'))

# %%
wh_2018.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'wh_2018_wrangled.csv'))

# %%
wh_2019.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'wh_2019_wrangled.csv'))

# %%
wh_2020_2.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'wh_2020_wrangled.csv'))

# %%
wh_2021_2.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'wh_2021_wrangled.csv'))

# %%
wh_2022_1.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'wh_2022_wrangled.csv'))

# %%
wh_2023_1.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'wh_2023_wrangled.csv'))
